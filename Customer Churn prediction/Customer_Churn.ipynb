# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df= pd.read_csv("Customerchurn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3134  7168-HDQHG  Female              0     Yes        Yes      36
# 2952  5260-UMPWX  Female              0     Yes        Yes      26
# 3212  0585-EGDDA    Male              0     Yes         No      40
# 3497  9799-CAYJJ  Female              1     Yes         No       2
# 1600  3068-OMWZA    Male              1      No         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3134          Yes            No              No  No internet service  ...
# 2952          Yes            No              No  No internet service  ...
# 3212          Yes            No     Fiber optic                   No  ...
# 3497          Yes            No     Fiber optic                   No  ...
# 1600          Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3134  No internet service  No internet service  No internet service
# 2952  No internet service  No internet service  No internet service
# 3212                  Yes                   No                   No
# 3497                   No                   No                   No
# 1600                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3134  No internet service  Month-to-month               No
# 2952  No internet service  Month-to-month              Yes
# 3212                   No  Month-to-month              Yes
# 3497                   No  Month-to-month              Yes
# 1600                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 3134  Bank transfer (automatic)          19.20         702.9    No
# 2952    Credit card (automatic)          20.25        493.95    No
# 3212           Electronic check          80.00       3168.75    No
# 3497           Electronic check          69.30         153.8    No
# 1600           Electronic check          88.80          88.8   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df1=df[df.TotalCharges != ' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\rajaw\AppData\Local\Temp\ipykernel_11088\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
tenure_churn_no=df1[df1.Churn=='No'].tenure
tenure_churn_yes=df1[df1.Churn=='Yes'].tenure
plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['red','green'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['red','green'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\rajaw\AppData\Local\Temp\ipykernel_11088\2045096646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# C:\Users\rajaw\AppData\Local\Temp\ipykernel_11088\2045096646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1638       1              0        1           1      68             1
# 5883       1              0        0           0      13             1
# 4589       1              0        1           1      10             1
# 4983       1              1        1           0      40             0
# 5672       1              0        1           0      49             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 1638              1               0             1                 1  ...
# 5883              0               0             0                 0  ...
# 4589              0               0             0                 0  ...
# 4983              0               0             1                 0  ...
# 5672              1               1             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 1638                    0                            1                   0
# 5883                    0                            0                   1
# 4589                    0                            0                   1
# 4983                    1                            0                   0
# 5672                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 1638                        0                  0                  1
# 5883                        1                  0                  0
# 4589                        0                  0                  1
# 4983                        1                  0                  0
# 5672                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 1638                                        0
# 5883                                        0
# 4589                                        0
# 4983                                        0
# 5672                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 1638                                      1                               0
# 5883                                      0                               0
# 4589                                      0                               0
# 4983                                      0                               1
# 5672                                      0                               1
#
#       PaymentMethod_Mailed check
# 1638                           0
# 5883                           1
# 4589                           1
# 4983                           0
# 5672                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5137 - accuracy: 0.7268
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.7929
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4198 - accuracy: 0.7993
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8034
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4141 - accuracy: 0.8021
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4117 - accuracy: 0.8064
# Epoch 7/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8039
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.8057
# Epoch 9/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8073
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4066 - accuracy: 0.8052
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4058 - accuracy: 0.8094
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8076
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4029 - accuracy: 0.8105
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8105
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4010 - accuracy: 0.8094
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4003 - accuracy: 0.8110
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8114
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8146
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3962 - accuracy: 0.8140
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8137
# Epoch 21/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8187
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3938 - accuracy: 0.8164
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8192
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8153
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3899 - accuracy: 0.8172
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8178
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8185
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3882 - accuracy: 0.8185
# Epoch 29/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3870 - accuracy: 0.8208
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8210
# Epoch 31/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3858 - accuracy: 0.8164
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3845 - accuracy: 0.8220
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3841 - accuracy: 0.8187
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8192
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8224
# Epoch 36/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8242
# Epoch 37/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8222
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8215
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3802 - accuracy: 0.8228
# Epoch 40/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.8222
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3793 - accuracy: 0.8224
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3802 - accuracy: 0.8212
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3791 - accuracy: 0.8235
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3773 - accuracy: 0.8256
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3767 - accuracy: 0.8238
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8235
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3763 - accuracy: 0.8256
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3752 - accuracy: 0.8268
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.8252
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.8276
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8279
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3739 - accuracy: 0.8258
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8267
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3719 - accuracy: 0.8260
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3727 - accuracy: 0.8261
# Epoch 56/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8261
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3698 - accuracy: 0.8265
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3705 - accuracy: 0.8309
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8308
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3690 - accuracy: 0.8293
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8293
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3685 - accuracy: 0.8284
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8299
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8297
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8302
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3660 - accuracy: 0.8277
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8286
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3649 - accuracy: 0.8295
# Epoch 69/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3652 - accuracy: 0.8309
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8286
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3640 - accuracy: 0.8304
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8299
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3629 - accuracy: 0.8329
# Epoch 74/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3630 - accuracy: 0.8324
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3621 - accuracy: 0.8322
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3618 - accuracy: 0.8322
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8318
# Epoch 78/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3609 - accuracy: 0.8341
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.8316
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8327
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8352
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8316
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3582 - accuracy: 0.8336
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3586 - accuracy: 0.8313
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3588 - accuracy: 0.8308
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3572 - accuracy: 0.8327
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3572 - accuracy: 0.8336
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8352
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3570 - accuracy: 0.8386
# Epoch 90/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3563 - accuracy: 0.8340
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3560 - accuracy: 0.8322
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8356
# Epoch 93/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3550 - accuracy: 0.8336
# Epoch 94/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8356
# Epoch 95/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3548 - accuracy: 0.8343
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3533 - accuracy: 0.8336
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3533 - accuracy: 0.8363
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8354
# Epoch 99/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8361
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8377

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 963us/step - loss: 0.4850 - accuracy: 0.7854
# [0.4850202798843384, 0.7853589057922363]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.31960687],
#        [0.7112989 ],
#        [0.01333924],
#        [0.7906281 ],
#        [0.45568922]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# C:\Users\rajaw\AppData\Local\Temp\ipykernel_11088\2588316582.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   y_test[:10]
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       999
#            1       0.65      0.57      0.60       408
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.72      0.73      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
accuracy=round((862+229)/(862+229+137+179),2)
print(accuracy)
# Out:
# 0.78

# %%
precision_0=round(862/(862+179),2)
print(precision_0)
# Out:
# 0.83

# %%
precison_1=round(229/(229+137),2)
print(precison_1)
# Out:
# 0.63

# %%
recall=round(862/(862+137),2)
print(recall)
# Out:
# 0.86
